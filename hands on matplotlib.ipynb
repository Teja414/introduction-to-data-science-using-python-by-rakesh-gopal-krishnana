# %%
import matplotlib as mp

# %%
from matplotlib import pyplot as plt

# %%
pyplot.plot([1,2,3],[1,2,4])
pyplot.show()

# %%
import pandas as pd

# %%
df = pd.Series(data = [1,2,3],index=('d1','d2','d3'))

# %%
df.plot(title="using inbuild plot of pandas")
# Out:
# <AxesSubplot: title={'center': 'using inbuild plot of pandas'}>

# %%
x = [1,2,3,4]
y = [3,4,5,6]

# %%
plt.plot(x,y,'b^')
plt.axis([0,20,0,20])
plt.title("just representation of points")
# Out:
# Text(0.5, 1.0, 'just representation of points')

# %%
plt.subplot(211)
plt.plot(x,y)
plt.subplot(212)
plt.plot(x,y,color="r")
